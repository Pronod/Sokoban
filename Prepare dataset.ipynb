# %%
import gym_sokoban.envs
from gym_sokoban.envs import SokobanEnv
from gym.spaces import Discrete, Box
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf
from collections import deque
from copy import deepcopy

# %%
env = SokobanEnv((10, 10), 100, 4)

# %%
def generate_dataset(env, num_iterations=500, max_iterations=100):
    solved = []
    dead_end = []
    for i in range(num_iterations):
        done = False
        env.reset()
        iteration = 0
        print("iteration", i)
        while not done:
            iteration += 1
            action = np.random.choice([1, 2, 3, 4])
            state, reward, done, _ = env.step(action)
            if done:
                if iteration == max_iterations:
                    dead_end.append(state)
                else:
                    solved.append(state)
    return np.array(solved), np.array(dead_end)

# %%
solved, dead_end = generate_dataset(env)
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# ...

# %%
solved.shape
# Out:
# (1, 160, 160, 3)

# %%
dead_end.shape
# Out:
# (499, 160, 160, 3)

# %%
np.save("dead_end_state_10x10", dead_end)

# %%
plt.imshow(dead_end[0])

# %%
def generate_solved(env, num_iterations=256, max_iterations=20):
    solved = []
    i = 0
    while len(solved) < num_iterations:
        done = False
        env.reset()
        iteration = 0
        i += 1
        while not done:
            iteration += 1
            action = np.random.choice([1, 2, 3, 4])
            state, reward, done, _ = env.step(action)
            if done and iteration < max_iterations:
                solved.append(state)
    return np.array(solved)

# %%
dead_end.shape[0] - solved.shape[0]

# %%
solved_more = generate_solved(env, dead_end.shape[0] - solved.shape[0], 50)

# %%
solved_final = np.concatenate([solved, solved_more])

# %%
solved_final.shape

# %%
dead_end.shape

# %%
np.save("solved_state_10x10", solved_final)
np.save("dead_end_state_10x10", dead_end)
