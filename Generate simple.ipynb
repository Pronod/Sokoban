# %%
import gym_sokoban.envs
from gym_sokoban.envs import SokobanEnv
from gym.spaces import Discrete, Box
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf
from collections import deque
from copy import deepcopy
from PIL import Image
from numpy import asarray

# %%
env = SokobanEnv((6, 6), 50, 2)
simple_fields = []

# %%
for i in range(3431):
    env.reset()
    field = env.render('rgb_array')
    simple_fields.append(deepcopy(field))
# Out:
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#3) to place 1 player and 2 boxes.
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Generated Model with score == 0
# [SOKOBAN] Retry . . .
# [SOKOBAN] Runtime Error/Warning: Not enough free spots (#3) to place 1 player and 2 boxes.
# [SOKOBAN] Retry . . .
# ...

# %%
plt.imshow(simple_fields[0])

# %%
simple_fields = np.array(simple_fields)
np.save("simple_state", simple_fields)
